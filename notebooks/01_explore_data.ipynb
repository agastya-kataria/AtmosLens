# %% [markdown]
# # Explore the AtmosLens sample cube
#
# Load the real NetCDF snapshot and inspect the xarray-backed air-quality forecast that powers the app.

# %%
import xarray as xr

ds = xr.load_dataset("../data/sample_forecast.nc")
ds

# %%
ds.pm2_5.isel(time=0).plot()
